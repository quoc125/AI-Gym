# %% [markdown]
# # Moutain Cart

# %%
import gym
import numpy as np

# %%
env = gym.make("MountainCar-v0")
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %% [markdown]
# ## Check the velcoity of the cart, as the cart's velocity drops to zero, the goes the opposite direction

# %%
env.reset()
prevState = -1
currentAction = 0
finish = False
while (not finish):
    env.render()
    state, reward, done, empty = env.step(currentAction)
    #Check velocity of the cart and change direction based on it
    if (prevState < 0 and state[1] > 0):
        print (state[1])
        currentAction = 2
    elif (prevState > 0 and state[1] < 0):
        print (state[1])
        print ("X")
        currentAction = 1
    prevState = state[1]
    done = finish
# Out:
# 0.0004818622650568174
# -0.0011409657304510918
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# -0.0023411562447730972
# X
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7033bf4f5719> in <module>()
#       4 finish = False
#       5 while (not finish):
# ----> 6     env.render()
#       7     state, reward, done, empty = env.step(currentAction)
#       8     #Check velocity of the cart and change direction based on it
#
# ~/anaconda3/lib/python3.7/site-packages/gym/core.py in render(self, mode, **kwargs)
#     273
#     274     def render(self, mode='human', **kwargs):
# --> 275         return self.env.render(mode, **kwargs)
#     276
#     277     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/gym/envs/classic_control/mountain_car.py in render(self, mode)
#     112         self.cartrans.set_rotation(math.cos(3 * pos))
#     113
# --> 114         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#     115
#     116     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/gym/envs/classic_control/rendering.py in render(self, return_rgb_array)
#     103             arr = arr.reshape(buffer.height, buffer.width, 4)
#     104             arr = arr[::-1,:,0:3]
# --> 105         self.window.flip()
#     106         self.onetime_geoms = []
#     107         return arr if return_rgb_array else self.isopen
#
# ~/anaconda3/lib/python3.7/site-packages/pyglet/window/xlib/__init__.py in flip(self)
#     504         # TODO canvas.flip?
#     505         if self.context:
# --> 506             self.context.flip()
#     507
#     508         self._sync_resize()
#
# ~/anaconda3/lib/python3.7/site-packages/pyglet/gl/xlib.py in flip(self)
#     290         if self._vsync:
#     291             self._wait_vsync()
# --> 292         glx.glXSwapBuffers(self.x_display, self.canvas.x_window)
#     293
#     294
#
# KeyboardInterrupt:

# %%
env.close()
